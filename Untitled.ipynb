# %% [markdown]
# # Customer Churn Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns

# %%
df=pd.read_csv('CustomerChurn.csv')

# %%
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
 df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# seniorcitizen is actually a categorical hence the 25%-50%-75% distribution is not proper

# %% [markdown]
# 75% customers have tenure less than 55 months

# %% [markdown]
# average monthly charges are USD 64.76 whereas 25% customers pay more then USD 89.85 per month

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
 df['Churn'].value_counts()/len(df)*100
# Out:
# No     73.463013
# Yes    26.536987
# Name: Churn, dtype: float64

# %%
df['Churn'].value_counts().plot(kind="bar",figsize=(8,6))
plt.xlabel("count",labelpad=14)
plt.ylabel("target variable",labelpad=14)
plt.title("count of TARGET variable per category",y=1.02)
# Out:
# Text(0.5, 1.02, 'count of TARGET variable per category')

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
 df['Churn'].value_counts()/len(df)*100
# Out:
# No     73.463013
# Yes    26.536987
# Name: Churn, dtype: float64

# %% [markdown]
# data is highly imbalanced , ratio=73:27

# %% [markdown]
# so we analyse the data with other features while taking the target values separately to get some insights

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ## Missing data- initial intution

# %% [markdown]
# .here , we don't have any missing data

# %% [markdown]
# General thumb rules:

# %% [markdown]
# for features with less missing values-can use regression to predict the misssing values of fill with the mean of the values present, depending on thefeatures

# %% [markdown]
# for features with very high number of  missing values- it is better to drop those columns as they give less insight on analysis

# %% [markdown]
# as there's no thumb rule on what criteria do we delete the columns with high number of missing values, but generally you can delete the columns, if you have more than 30-40% of missing values. but again there a catch here, for example. is_car & car_type . people having no cars , will obviously have car_type as nan(null), but that does'nt make this column useless, so decisions has to be taken wisely

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# 1. create a copy of base data for manuplation & processing

# %%
new_df=df.copy()

# %%
new_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# 2. total charges should be numeric amount. let's convert it to numerical data type

# %%
new_df.TotalCharges=pd.to_numeric(new_df.TotalCharges,errors='coerce')
new_df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# 3. as we can see there are 11 missing values in TotalCharges column. let's check these records

# %%
new_df.loc[new_df['TotalCharges'].isnull()]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
# 4. missing values treatment

# %% [markdown]
# since the % of these records compared to total dataset is very low is 0.15%. it is safe to ignore them further processing.

# %%
new_df.dropna()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# 5. divide customers into bins based on tenure<12 months:assign a tenue group if 1-12, for tenure between 1 to 12 yrs, tenure group of 13-24 so on..

# %%
 print(new_df['tenure'].max())
# Out:
# 72

# %%
labels=["{0}-{1}".format(i,i+11)for i in range(1,72,12)]
print(labels)
# Out:
# ['1-12', '13-24', '25-36', '37-48', '49-60', '61-72']

# %%
labels=["{0}-{1}".format(i,i+11)for i in range(1,72,12)]
new_df['tenure_group']=pd.cut(new_df.tenure,range(1,80,12),right=False,labels=labels)

# %%
new_df['tenure_group'].value_counts()
# Out:
# 1-12     2175
# 61-72    1407
# 13-24    1024
# 25-36     832
# 49-60     832
# 37-48     762
# Name: tenure_group, dtype: int64

# %%
new_df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %% [markdown]
# 6. remove column not required for processing

# %%
new_df.drop(columns=['customerID','tenure'],axis=1,inplace=True)

# %%
new_df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %% [markdown]
# # #Data exploration

# %% [markdown]
# 1. plot distibution of individual predictors by churn

# %%
new_df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %% [markdown]
# ## univariate analysis

# %%
for i,predictor in enumerate(new_df.drop(columns=['Churn','TotalCharges','MonthlyCharges'])):
    plt.figure(i)
    sns.countplot(data=new_df,x=predictor,hue='Churn')

# %% [markdown]
# ## Numerical analysis

# %%
new_df.gender.value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
new_df1_target0=new_df[new_df["Churn"]=='No']
new_df1_target1=new_df[new_df["Churn"]=='Yes']

# %%
new_df1_target1.gender.value_counts()
# Out:
# Female    939
# Male      930
# Name: gender, dtype: int64

# %%
new_df.gender.value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
pd.crosstab(new_df.PaymentMethod,new_df.Churn)
# Out:
# Churn                        No   Yes
# PaymentMethod
# Bank transfer (automatic)  1286   258
# Credit card (automatic)    1290   232
# Electronic check           1294  1071
# Mailed check               1304   308

# %% [markdown]
# 2. convert the target variable 'Churn' in a binary numericc variable i.e.Yes=1, No=0

# %%
new_df['Churn']=np.where(new_df.Churn=='Yes',1,0)

# %%
new_df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %% [markdown]
# 3.convert all the categorical variables into dummy variables

# %%
new_df_dummies=pd.get_dummies(new_df)
new_df_dummies.head()
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0           29.85         29.85      0              1
# 1              0           56.95       1889.50      0              0
# 2              0           53.85        108.15      1              0
# 3              0           42.30       1840.75      0              0
# 4              0           70.70        151.65      1              1
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0            0           0            1              1               0  ...
# 1            1           1            0              1               0  ...
# 2            1           1            0              1               0  ...
# 3            1           1            0              1               0  ...
# 4            0           1            0              1               0  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                        0
# ...

# %% [markdown]
# 4. relationship between monthly charges and total charges

# %%
sns.lmplot(data=new_df_dummies,x='MonthlyCharges',y='TotalCharges',fit_reg=False)

# %%
new_df_dummies['MonthlyCharges'].corr(new_df_dummies['TotalCharges'])
# Out:
# 0.6510648032262024

# %% [markdown]
# total charges increases as monthly charges increase-as expected

# %% [markdown]
# 10. churn by monthly charges and total charges

# %%
Mth=sns.kdeplot(new_df_dummies.MonthlyCharges[(new_df_dummies['Churn']==0)],color='Red',shade=True)
Mth=sns.kdeplot(new_df_dummies.MonthlyCharges[(new_df_dummies['Churn']==1)],ax=Mth,color='Blue',shade=True)
Mth.legend(['No Churn','Churn'],loc='upper right')
Mth.set_ylabel("Density")
Mth.set_xlabel('Monthly Charges')
Mth.set_title("Monthly charges by churn")
# Out:
# C:\Users\91934\AppData\Local\Temp\ipykernel_20768\2348171397.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Mth=sns.kdeplot(new_df_dummies.MonthlyCharges[(new_df_dummies['Churn']==0)],color='Red',shade=True)
# C:\Users\91934\AppData\Local\Temp\ipykernel_20768\2348171397.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Mth=sns.kdeplot(new_df_dummies.MonthlyCharges[(new_df_dummies['Churn']==1)],ax=Mth,color='Blue',shade=True)
# Text(0.5, 1.0, 'Monthly charges by churn')

# %% [markdown]
# insight: churn is high when monthly charges are high

# %%
Tot=sns.kdeplot(new_df_dummies.TotalCharges[(new_df_dummies['Churn']==0)],color='Red',shade=True)
Tot=sns.kdeplot(new_df_dummies.TotalCharges[(new_df_dummies['Churn']==1)],ax=Tot,color='Blue',shade=True)
Tot.legend(['No Churn','Churn'],loc='upper right')
Tot.set_ylabel("Density")
Tot.set_xlabel('Total Charges')
Tot.set_title("Total charges by churn")
# Out:
# C:\Users\91934\AppData\Local\Temp\ipykernel_20768\3433801751.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Tot=sns.kdeplot(new_df_dummies.TotalCharges[(new_df_dummies['Churn']==0)],color='Red',shade=True)
# C:\Users\91934\AppData\Local\Temp\ipykernel_20768\3433801751.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Tot=sns.kdeplot(new_df_dummies.TotalCharges[(new_df_dummies['Churn']==1)],ax=Tot,color='Blue',shade=True)
# Text(0.5, 1.0, 'Total charges by churn')

# %% [markdown]
# * surprising insight* as higher churn at lower total charges

# %% [markdown]
# however if we combine the insights of 3 parameters.i.e tenure monthly charges & total charges then the picture is bit clear-higher monthly charge at lower tenure results into lower total charge . hence all these 3 factors viz higher montly chargee. lower tenure and lower total charge are linked to higt churn

# %% [markdown]
# 11. build a corelation of all predicators with churn

# %%
plt.figure(figsize=(20,8))
new_df_dummies.corr()['Churn'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# *derived insight*

# %% [markdown]
# high churn seen in case of month to month contracts no online security no tech support, first year of subscription and fibre optics internet

# %% [markdown]
# low churn is seen in case of long term contacts. subscriptions without internet service and the customers engaged for 5+ years

# %% [markdown]
# factors like gender.availability of phoneservice and # of multiple lines have almost no impact on churn

# %% [markdown]
# this is also evident from the heatmap below

# %%
plt.figure(figsize=(12,12))
sns.heatmap(new_df_dummies.corr(),cmap='Paired')
# Out:
# <Axes: >

# %%
Tot=sns.kdeplot(df.tenure[(df['Churn']=='No')],color='Red',shade=True)
Tot=sns.kdeplot(df.tenure[(df['Churn']=='Yes')],ax=Tot,color='Blue',shade=True)
Tot.legend(['No Churn','Churn'],loc='upper right')
Tot.set_ylabel("Density")
Tot.set_xlabel('Total Charges')
Tot.set_title("Total charges by churn")
# Out:
# C:\Users\91934\AppData\Local\Temp\ipykernel_20768\3078776983.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Tot=sns.kdeplot(df.tenure[(df['Churn']=='No')],color='Red',shade=True)
# C:\Users\91934\AppData\Local\Temp\ipykernel_20768\3078776983.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Tot=sns.kdeplot(df.tenure[(df['Churn']=='Yes')],ax=Tot,color='Blue',shade=True)
# Text(0.5, 1.0, 'Total charges by churn')

# %% [markdown]
# ## Bivariate analysis

# %%
new_df1_target0=new_df.loc[new_df['Churn']==0]
new_df1_target1=new_df.loc[new_df['Churn']==1]

# %%
len(new_df1_target0)
# Out:
# 5174

# %%
len(new_df1_target1)
# Out:
# 1869

# %%
def uniplot(df,col,title,hue=None):
    sns.set_style('whitegrid')
    sns.set_context("talk")
    plt.rcParams["axes.labelsize"]=20
    plt.rcParams["axes.titlesize"]=22
    plt.rcParams["axes.titlepad"]=30
    
    temp=pd.Series(data=hue)
    fig,ax=plt.subplots()
    width=len(df[col].unique())+7+4*len(temp.unique())
    fig.set_size_inches(width,8)
    plt.xticks(rotation=45)
    plt.yscale('log')
    plt.title(title)
    ax=sns.countplot(data=df,x=col,order=df[col].value_counts().index,hue=hue,palette='bright')
    plt.show()

# %%
uniplot(new_df1_target1,col="Partner",title="distribution of gender for churned customers",hue="gender")

# %%
uniplot(new_df1_target0,col="Partner",title="distribution of gender for churned customers",hue="gender")

# %%
uniplot(new_df1_target0,col="PaymentMethod",title="distribution of gender for churned customers",hue="gender")

# %%
uniplot(new_df1_target0,col="Contract",title="distribution of gender for churned customers",hue="gender")

# %%
uniplot(new_df1_target0,col="TechSupport",title="distribution of gender for churned customers",hue="gender")

# %%
uniplot(new_df1_target0,col="SeniorCitizen",title="distribution of gender for churned customers",hue="gender")

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# these are some of the quick insights from this exercise

# %% [markdown]
# 1. electronic check medium are the highest churners

# %% [markdown]
# 2. contact type- monthly customers are more likely to churn because of no contract terms ,as they are free to go customers

# %% [markdown]
# 3. no online security . no tech support category are high churners

# %% [markdown]
# 4. non senior citizens are high churners

# %% [markdown]
# ------END----------
